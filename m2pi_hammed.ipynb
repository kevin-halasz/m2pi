# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib notebook
from sklearn.linear_model import LinearRegression

# %%
df_1996 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/census_lf_1996.csv')
df_1996
# Out:
#        Geography                Labour Force Ac  Total - Age groups  \
# 0              0  Total - Labour force activity          22628925.0
# 1              0             Total labour force          14812700.0
# 2              0                       Employed          13318740.0
# 3              0                     Unemployed           1493960.0
# 4              0        Not in the labour force           7816225.0
# ...          ...                            ...                 ...
# 44347    6108095                     Unemployed                15.0
# 44348    6108095        Not in the labour force                85.0
# 44349    6108095             Participation rate                68.6
# 44350    6108095                Employment rate                62.7
# 44351    6108095              Unemployment rate                 8.6
#
#          15-24 years      15-19 years      20-24 years    25-34 years  \
# 0          3849025.0        1956115.0        1892910.0      4481315.0
# ...

# %%
df_1996['Labour Force Ac'][3]
# Out:
# '    Unemployed'

# %%
df1_1996=df_1996.loc[df_1996['Labour Force Ac'] == 'Unemployment rate']
df1_1996
# Out:
#        Geography    Labour Force Ac  Total - Age groups    15-24 years  \
# 7              0  Unemployment rate                10.1           17.7
# 15            10  Unemployment rate                25.1           36.9
# 23          1001  Unemployment rate                19.2           29.9
# 31       1001105  Unemployment rate                43.8            0.0
# 39       1001109  Unemployment rate                 0.0            0.0
# ...          ...                ...                 ...            ...
# 44319    6108068  Unemployment rate                 0.0            0.0
# 44327    6108073  Unemployment rate                 8.7           12.0
# 44335    6108081  Unemployment rate                27.8           46.2
# 44343    6108087  Unemployment rate                19.1           40.0
# 44351    6108095  Unemployment rate                 8.6            0.0
#
#            15-19 years      20-24 years    25-34 years    35-44 years  \
# ...

# %%
df2_1996=df1_1996.loc[df1_1996['Geography'].isin([5947,5949,5951,5957])]
df2_1996
# Out:
#        Geography    Labour Force Ac  Total - Age groups    15-24 years  \
# 42751       5947  Unemployment rate                16.5           27.0
# 42855       5949  Unemployment rate                13.7           21.0
# 43111       5951  Unemployment rate                12.5           19.9
# 43519       5957  Unemployment rate                 9.7           13.0
#
#            15-19 years      20-24 years    25-34 years    35-44 years  \
# 42751             24.0             29.3           17.3           11.5
# 42855             20.0             21.4           13.8           11.6
# 43111             16.7             22.2           13.0           10.5
# 43519             33.3             11.8           11.9           10.0
#
#          45-54 years    55-64 years    65 years and over
# 42751           11.1           21.2                 21.2
# 42855           12.0            9.7                 10.0
# 43111            8.0           14.0                  2.9
# ...

# %%
#plt.figure(figsize=(10, 10))
#df2_1996.plot.bar(x='Geography', y = 'Total - Age groups', rot=0)

# %%
#df3_1996 = df1_1996[:10]
#df3_1996

# %%
df11_1996=df_1996.loc[df_1996['Labour Force Ac'] == '    Unemployed']
df11_1996

df21_1996=df11_1996.loc[df11_1996['Geography'].isin([5947,5949,5951,5957])]
df21_1996

#sumUE_1996 = sum(df21_1996['Total - Age groups'])
#sumUE_1996
# Out:
#        Geography Labour Force Ac  Total - Age groups    15-24 years  \
# 42747       5947      Unemployed              2245.0          615.0
# 42851       5949      Unemployed              3105.0          830.0
# 43107       5951      Unemployed              2755.0          825.0
# 43515       5957      Unemployed                75.0           15.0
#
#            15-19 years      20-24 years    25-34 years    35-44 years  \
# 42747            220.0            400.0          615.0          445.0
# 42851            330.0            495.0          780.0          745.0
# 43107            300.0            520.0          700.0          635.0
# 43515             10.0             10.0           25.0           20.0
#
#          45-54 years    55-64 years    65 years and over
# 42747          295.0          230.0                 35.0
# 42851          545.0          175.0                 30.0
# 43107          330.0          245.0                 15.0
# ...

# %%
df12_1996=df_1996.loc[df_1996['Labour Force Ac'] == '  Total labour force']
df12_1996

df22_1996=df12_1996.loc[df12_1996['Geography'].isin([5947,5949,5951,5957])]
df22_1996

#sumTLF_1996 = sum(df22_1996['Total - Age groups'])
#sumTLF_1996
# Out:
#        Geography       Labour Force Ac  Total - Age groups    15-24 years  \
# 42745       5947    Total labour force             13620.0         2275.0
# 42849       5949    Total labour force             22670.0         3960.0
# 43105       5951    Total labour force             21965.0         4150.0
# 43513       5957    Total labour force               775.0          115.0
#
#            15-19 years      20-24 years    25-34 years    35-44 years  \
# 42745            915.0           1365.0         3555.0         3875.0
# 42849           1650.0           2310.0         5670.0         6400.0
# 43105           1800.0           2345.0         5385.0         6065.0
# 43513             30.0             85.0          210.0          200.0
#
#          45-54 years    55-64 years    65 years and over
# 42745         2660.0         1085.0                165.0
# 42849         4535.0         1795.0                300.0
# 43105         4100.0         1750.0                510.0
# ...

# %%
#Rt_96=sumUE_1996/sumTLF_1996

#Rt_96=Rt_96*100

Rt_96=(75/775)*100
Rt_96
#plt.figure(figsize=(40, 50))
#df2_1996.plot.bar(x='Geography', y = 'Total - Age groups', rot=0)
# Out:
# 9.67741935483871

# %%
df_2001 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/census_lf_2001.csv')
df_2001
# Out:
#        Geography                Labour Force Ac  Total - Age groups  \
# 0              1  Total - Labour force activity          23901360.0
# 1              1            In the labour force          15872070.0
# 2              1                       Employed          14695130.0
# 3              1                     Unemployed           1176935.0
# 4              1        Not in the labour force           8029285.0
# ...          ...                            ...                 ...
# 40859    6208087                     Unemployed                65.0
# 40860    6208087        Not in the labour force               170.0
# 40861    6208087             Participation rate                59.3
# 40862    6208087                Employment rate                43.0
# 40863    6208087              Unemployment rate                25.5
#
#          15-24 years      15-19 years      20-24 years    25-34 years  \
# 0          3988200.0        2044355.0        1943850.0      3973085.0
# ...

# %%
df_2001['Labour Force Ac'][1]
# Out:
# '  In the labour force'

# %%
df1_2001=df_2001.loc[df_2001['Labour Force Ac'] == 'Unemployment rate']
df1_2001
# Out:
#        Geography    Labour Force Ac  Total - Age groups    15-24 years  \
# 7              1  Unemployment rate                 7.4           13.7
# 15            10  Unemployment rate                21.8           33.1
# 23          1001  Unemployment rate                15.6           27.0
# 31       1001105  Unemployment rate                22.2            0.0
# 39       1001109  Unemployment rate                 0.0            0.0
# ...          ...                ...                 ...            ...
# 40831    6208047  Unemployment rate                11.6            0.0
# 40839    6208059  Unemployment rate                22.8           40.0
# 40847    6208073  Unemployment rate                14.4           30.4
# 40855    6208081  Unemployment rate                26.8           38.5
# 40863    6208087  Unemployment rate                25.5           50.0
#
#            15-19 years      20-24 years    25-34 years      25-29 years  \
# ...

# %%
df2_2001=df1_2001.loc[df1_2001['Geography'].isin([5947,5949,5951,5957])]
df2_2001
# Out:
#        Geography    Labour Force Ac  Total - Age groups    15-24 years  \
# 39207       5947  Unemployment rate                16.5           25.9
# 39319       5949  Unemployment rate                17.1           27.7
# 39583       5951  Unemployment rate                12.6           18.8
# 40047       5957  Unemployment rate                18.1           37.5
#
#            15-19 years      20-24 years    25-34 years      25-29 years  \
# 39207             25.2             26.6           20.4             23.3
# 39319             32.2             23.8           21.0             24.4
# 39583             18.7             18.9           14.9             15.6
# 40047              0.0             38.5           18.2             10.5
#
#            30-34 years    35-44 years      35-39 years      40-44 years  \
# 39207             17.5           13.9             15.2             12.6
# 39319             18.1           14.3             16.1             12.8
# ...

# %%
#plt.figure(figsize=(10, 10))
#df2_2001.plot.bar(x='Geography', y = 'Total - Age groups', rot=0)

# %%
df11_2001=df_2001.loc[df_2001['Labour Force Ac'] == '    Unemployed']
df11_2001

df21_2001=df11_2001.loc[df11_2001['Geography'].isin([5947,5949,5951,5957])]
df21_2001

#sumUE_2001 = sum(df21_2001['Total - Age groups'])
#sumUE_2001
# Out:
#        Geography Labour Force Ac  Total - Age groups    15-24 years  \
# 39203       5947      Unemployed              1950.0          410.0
# 39315       5949      Unemployed              3620.0          875.0
# 39579       5951      Unemployed              2735.0          700.0
# 40043       5957      Unemployed               135.0           30.0
#
#            15-19 years      20-24 years    25-34 years      25-29 years  \
# 39203            180.0            230.0          510.0            270.0
# 39315            500.0            380.0          935.0            480.0
# 39579            345.0            355.0          650.0            315.0
# 40043              0.0             25.0           30.0             10.0
#
#            30-34 years    35-44 years      35-39 years      40-44 years  \
# 39203            235.0          455.0            250.0            205.0
# 39315            450.0          830.0            440.0            395.0
# ...

# %%
df12_2001=df_2001.loc[df_2001['Labour Force Ac'] == '  In the labour force']
df12_2001

df22_2001=df12_2001.loc[df12_2001['Geography'].isin([5947,5949,5951,5957])]
df22_2001

#sumTLF_2001 = sum(df22_2001['Total - Age groups'])
#sumTLF_2001
# Out:
#        Geography        Labour Force Ac  Total - Age groups    15-24 years  \
# 39201       5947    In the labour force             11840.0         1580.0
# 39313       5949    In the labour force             21130.0         3155.0
# 39577       5951    In the labour force             21630.0         3725.0
# 40041       5957    In the labour force               745.0           80.0
#
#            15-19 years      20-24 years    25-34 years      25-29 years  \
# 39201            715.0            865.0         2500.0           1160.0
# 39313           1555.0           1600.0         4460.0           1970.0
# 39577           1845.0           1875.0         4365.0           2015.0
# 40041             15.0             65.0          165.0             95.0
#
#            30-34 years    35-44 years      35-39 years      40-44 years  \
# 39201           1345.0         3275.0           1645.0           1625.0
# 39313           2490.0         5815.0           2735.0           3080.0
# ...

# %%
#Rt_01=sumUE_2001/sumTLF_2001

Rt_01=(135/745)*100

Rt_01
# Out:
# 18.120805369127517

# %%
df_2006 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/census_lf_2006.csv')
df_2006
# Out:
#        Geography                Labour force ac  Total - Age groups  \
# 0              1  Total - Labour force activity          25664220.0
# 1              1            In the labour force          17146135.0
# 2              1                       Employed          16021180.0
# 3              1                     Unemployed           1124960.0
# 4              1        Not in the labour force           8518090.0
# ...          ...                            ...                 ...
# 38691    6208087                     Unemployed                80.0
# 38692    6208087        Not in the labour force               215.0
# 38693    6208087             Participation rate                57.6
# 38694    6208087                Employment rate                40.4
# 38695    6208087              Unemployment rate                28.1
#
#          15 to 24 years    25 to 54 years      25 to 34 years  \
# 0             4207810.0        13732585.0           3987075.0
# ...

# %%
df_2006['Labour force ac'][1]
# Out:
# '  In the labour force'

# %%
df1_2006=df_2006.loc[df_2006['Labour force ac'] == 'Unemployment rate']
df1_2006
# Out:
#        Geography    Labour force ac  Total - Age groups    15 to 24 years  \
# 7              1  Unemployment rate                 6.6              12.8
# 15            10  Unemployment rate                18.6              26.8
# 23          1001  Unemployment rate                13.0              21.4
# 31       1001105  Unemployment rate                52.0               0.0
# 39       1001113  Unemployment rate                28.6              21.4
# ...          ...                ...                 ...               ...
# 38663    6208047  Unemployment rate                21.3              37.5
# 38671    6208059  Unemployment rate                22.0              36.8
# 38679    6208073  Unemployment rate                 9.7              19.2
# 38687    6208081  Unemployment rate                28.4              53.3
# 38695    6208087  Unemployment rate                28.1              53.8
#
#          25 to 54 years      25 to 34 years      35 to 44 years  \
# ...

# %%
#df2_2006 = df1_2006[:10]
#df2_2006

df2_2006=df1_2006.loc[df1_2006['Geography'].isin([5947,5949,5951,5957])]
df2_2006
# Out:
#        Geography    Labour force ac  Total - Age groups    15 to 24 years  \
# 37087       5947  Unemployment rate                15.0              22.4
# 37199       5949  Unemployment rate                14.2              25.4
# 37415       5951  Unemployment rate                10.3              13.8
# 37879       5957  Unemployment rate                10.1              21.4
#
#          25 to 54 years      25 to 34 years      35 to 44 years  \
# 37087              13.8                15.9                13.4
# 37199              12.4                14.9                13.3
# 37415               9.4                11.7                 8.2
# 37879              11.9                11.5                14.7
#
#            45 to 54 years    55 to 64 years    65 to 74 years  \
# 37087                12.9              14.1              12.8
# 37199                10.1              10.4              14.5
# 37415                 8.9              10.9               8.3
# ...

# %%
#plt.figure(figsize=(10, 10))
#df2_2006.plot.bar(x='Geography', y = 'Total - Age groups', rot=0)

# %%
df11_2006=df_2006.loc[df_2006['Labour force ac'] == '    Unemployed']
df11_2006

df21_2006=df11_2006.loc[df11_2006['Geography'].isin([5947,5949,5951,5957])]
df21_2006

#sumUE_2006 = sum(df21_2006['Total - Age groups'])
#sumUE_2006
# Out:
#        Geography Labour force ac  Total - Age groups    15 to 24 years  \
# 37083       5947      Unemployed              1600.0             330.0
# 37195       5949      Unemployed              2740.0             725.0
# 37411       5951      Unemployed              2120.0             460.0
# 37875       5957      Unemployed                70.0              15.0
#
#          25 to 54 years      25 to 34 years      35 to 44 years  \
# 37083            1005.0               285.0               350.0
# 37195            1660.0               480.0               655.0
# 37411            1300.0               420.0               385.0
# 37875              50.0                15.0                25.0
#
#            45 to 54 years    55 to 64 years    65 to 74 years  \
# 37083               370.0             230.0              30.0
# 37195               525.0             280.0              50.0
# 37411               485.0             310.0              45.0
# ...

# %%
df12_2006=df_2006.loc[df_2006['Labour force ac'] == '  In the labour force']
df12_2006

df22_2006=df12_2006.loc[df12_2006['Geography'].isin([5947,5949,5951,5957])]
df22_2006

#sumTLF_2006 = sum(df22_2006['Total - Age groups'])
#sumTLF_2006
# Out:
#        Geography        Labour force ac  Total - Age groups    15 to 24 years  \
# 37081       5947    In the labour force             10665.0            1470.0
# 37193       5949    In the labour force             19345.0            2855.0
# 37409       5951    In the labour force             20670.0            3345.0
# 37873       5957    In the labour force               690.0              70.0
#
#          25 to 54 years      25 to 34 years      35 to 44 years  \
# 37081            7280.0              1790.0              2610.0
# 37193           13385.0              3230.0              4935.0
# 37409           13760.0              3585.0              4720.0
# 37873             420.0               130.0               170.0
#
#            45 to 54 years    55 to 64 years    65 to 74 years  \
# 37081              2875.0            1635.0             235.0
# 37193              5220.0            2700.0             345.0
# 37409              5445.0            2850.0             540.0
# ...

# %%
#Rt_06=sumUE_2006/sumTLF_2006

Rt_06=(70/690)*100

Rt_06
# Out:
# 10.144927536231885

# %%
df_2011 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/census_lf_2011.csv')
df_2011
# Out:
#        Geography              Labour force st  Total - Age groups  \
# 0              1  Total - Labour force status          27259525.0
# 1              1          In the labour force          17990080.0
# 2              1                     Employed          16595030.0
# 3              1                   Unemployed           1395050.0
# 4              1      Not in the labour force           9269445.0
# ...          ...                          ...                 ...
# 29963    6208087                   Unemployed                80.0
# 29964    6208087      Not in the labour force               270.0
# 29965    6208087           Participation rate                51.3
# 29966    6208087              Employment rate                37.2
# 29967    6208087            Unemployment rate                27.6
#
#          15 to 24 years      15 to 19 years      20 to 24 years  \
# 0             4324070.0           2160275.0           2163795.0
# ...

# %%
df_2011['Labour force st'][3]
# Out:
# '    Unemployed'

# %%
df1_2011=df_2011.loc[df_2011['Labour force st'] == 'Unemployment rate']
df1_2011
# Out:
#        Geography    Labour force st  Total - Age groups    15 to 24 years  \
# 7              1  Unemployment rate                 7.8              16.6
# 15            10  Unemployment rate                14.6              22.9
# 23          1001  Unemployment rate                 9.8              18.0
# 31       1001101  Unemployment rate                 0.0               0.0
# 39       1001105  Unemployment rate                50.0               0.0
# ...          ...                ...                 ...               ...
# 29935    6208047  Unemployment rate                25.6              42.9
# 29943    6208059  Unemployment rate                30.9              59.1
# 29951    6208073  Unemployment rate                14.4              26.7
# 29959    6208081  Unemployment rate                33.0              50.0
# 29967    6208087  Unemployment rate                27.6              35.7
#
#            15 to 19 years      20 to 24 years    25 to 64 years  \
# ...

# %%
df2_2011=df1_2011.loc[df1_2011['Geography'].isin([5947,5949,5951,5957])]
df2_2011
# Out:
#        Geography    Labour force st  Total - Age groups    15 to 24 years  \
# 28591       5947  Unemployment rate                14.2              30.2
# 28631       5949  Unemployment rate                12.9              23.8
# 28815       5951  Unemployment rate                10.5              17.2
# 29247       5957  Unemployment rate                19.4               0.0
#
#            15 to 19 years      20 to 24 years    25 to 64 years  \
# 28591                25.6                33.1              12.2
# 28631                21.4                25.5              11.1
# 28815                13.5                20.8               9.3
# 29247                 0.0                 0.0              19.0
#
#            25 to 44 years      45 to 64 years    65 years and over
# 28591                14.1                10.5                  9.8
# 28631                12.8                 9.6                  8.6
# 28815                 9.1                 9.4                  9.9
# ...

# %%
#plt.figure(figsize=(10, 10))
#df2_2011.plot.bar(x='Geography', y = 'Total - Age groups', rot=0)

# %%
df11_2011=df_2011.loc[df_2011['Labour force st'] == '    Unemployed']
df11_2011

df21_2011=df11_2011.loc[df11_2011['Geography'].isin([5947,5949,5951,5957])]
df21_2011

sumUE_2011 = sum(df21_2011['Total - Age groups'])
sumUE_2011
# Out:
# 5985.0

# %%
df12_2011=df_2011.loc[df_2011['Labour force st'] == '  In the labour force']
df12_2011

df22_2011=df12_2011.loc[df12_2011['Geography'].isin([5947,5949,5951,5957])]
df22_2011

sumTLF_2011 = sum(df22_2011['Total - Age groups'])
sumTLF_2011
# Out:
# 49095.0

# %%
Rt_11=sumUE_2011/sumTLF_2011

Rt_11=Rt_11*100

Rt_11
# Out:
# 12.190650779101741

# %%
df2r_1996 = df2_1996[['Geography', 'Total - Age groups']]
df2r_2001 = df2_2001[['Geography', 'Total - Age groups']]
df2r_2011 = df2_2011[['Geography', 'Total - Age groups']]
dfr = pd.concat([df2r_1996, df2r_2001, df2r_2011], axis=0)
year = [1996, 1996, 1996, 1996, 2001, 2001, 2001, 2001, 2011, 2011, 2011, 2011]
dfr['year'] = year
# dfr = pd.concat([pd.DataFrame([]), dfr], axis=1)

dfr.to_csv('m2pi.csv')
dfr
# Out:
#        Geography  Total - Age groups  year
# 42751       5947                16.5  1996
# 42855       5949                13.7  1996
# 43111       5951                12.5  1996
# 43519       5957                 9.7  1996
# 39207       5947                16.5  2001
# 39319       5949                17.1  2001
# 39583       5951                12.6  2001
# 40047       5957                18.1  2001
# 28591       5947                14.2  2011
# 28631       5949                12.9  2011
# 28815       5951                10.5  2011
# 29247       5957                19.4  2011

# %%
#df_2006['Labour force ac'][38695]

# %%
df_2016 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/census_lfstat_2016.csv')
df_2016
# Out:
#           sgc  level                       name   total    inlf    empl  \
# 0          10      1  Newfoundland and Labrador  437935  256850  216705
# 1        1010      2           Avalon Peninsula  226090  141845  126905
# 2        1001      3             Division No. 1  226160  141865  126910
# 3     1001105      4        Portugal Cove South     205     130      75
# 4     1001113      4                  Trepassey     365     155     120
# ...       ...    ...                        ...     ...     ...     ...
# 4935  6208047      4                   Kugaaruk     570     335     225
# 4936  6208059      4                  Kugluktuk    1025     670     480
# 4937  6208073      4              Cambridge Bay    1270     930     775
# 4938  6208081      4                 Gjoa Haven     825     530     340
# 4939  6208087      4                   Taloyoak     640     390     230
#
#       unempl   nonlf  empl_rate  part_rate  unempl_rate
# ...

# %%
df1_2016=df_2016.loc[df_2016['sgc'].isin([5947,5949,5951,5957])]
df1_2016
# Out:
#        sgc  level                    name  total   inlf   empl  unempl  nonlf  \
# 4733  5947      3  Skeena-Queen Charlotte  14630   9765   8560    1205   4865
# 4749  5949      3         Kitimat-Stikine  30045  19340  16665    2670  10710
# 4782  5951      3         Bulkley-Nechako  30175  20180  17700    2480   9995
# 4811  5957      3                 Stikine    635    405    310      95    230
#
#       empl_rate  part_rate  unempl_rate
# 4733       58.5       66.7         12.3
# 4749       55.5       64.4         13.8
# 4782       58.7       66.9         12.3
# 4811       48.8       63.8         23.5

# %%
#plt.figure(figsize=(10, 10))
#df1_2016.plot.bar(x='sgc', y = 'unempl_rate', rot=0)
(2480/20180)*100
# Out:
# 12.289395441030724

# %%
sumUE_2016 = sum(df1_2016['unempl'])
sumUE_2016


sumTLF_2016 = sum(df1_2016['inlf'])
sumTLF_2016


Rt_16=sumUE_2016/sumTLF_2016

Rt_16=Rt_16*100

Rt_16
# Out:
# 12.980478969611593

# %%
df_NC = pd.read_csv("C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/lfs_north_coast.csv")
#df_NC

# %%
df1_NC=df_NC.loc[df_NC['Labour force characteristics'] == 'Unemployment rate']
df1_NC
# Out:
#      REF_DATE                                        GEO  DGUID  \
# 3724  2006-03  North Coast and Nechako, British Columbia    NaN
# 3725  2006-04  North Coast and Nechako, British Columbia    NaN
# 3726  2006-05  North Coast and Nechako, British Columbia    NaN
# 3727  2006-06  North Coast and Nechako, British Columbia    NaN
# 3728  2006-07  North Coast and Nechako, British Columbia    NaN
# ...       ...                                        ...    ...
# 4307  2022-02  North Coast and Nechako, British Columbia    NaN
# 4308  2022-03  North Coast and Nechako, British Columbia    NaN
# 4309  2022-04  North Coast and Nechako, British Columbia    NaN
# 4310  2022-05  North Coast and Nechako, British Columbia    NaN
# 4311  2022-06  North Coast and Nechako, British Columbia    NaN
#
#      Labour force characteristics                               Statistics  \
# 3724            Unemployment rate                                 Estimate
# ...

# %%
#df2_NC=df1_NC.loc[df_NC['Statistics'] == 'Estimate']
#df2_NC

# %%
#plt.figure(figsize=(10, 10))
#df2_NC.plot.bar(x='REF_DATE', y = 'VALUE', rot=0)

# %%
df_Reg = pd.read_csv("C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/data_Geo.csv")
df_Reg
# Out:
#                       SGC  Geography  1996  2001  2006  2011  2016
# 0  Skeena-Queen Charlotte       5947  16.5  16.5  15.0  14.2  12.3
# 1         Kitimat-Stikine       5949  13.7  17.1  14.2  12.9  13.8
# 2        Bulkley-Nechako        5951  12.5  12.6  10.3  10.5  12.3
# 3                 Stikine       5957   9.7  18.1  10.1  19.4  23.5

# %%
#plt.style.use("fivethirtyeight")
#create the base axis
fig, ax = plt.subplots(1,1, figsize = (15,8))#set the labels
#and the x positions
label = df_Reg["SGC"]
x = np.arange(len(label))#set the width of the bars
width = 0.2#create the first bar -1 width
rect1 = ax.bar(x -1.5*width,
              df_Reg["1996"],
              width = width, 
               label = 1996,
               edgecolor = "black")#create the second bar using x
rect2 = ax.bar(x -0.5*width,
              df_Reg["2001"],
              width = width,
              label = 2001,
              edgecolor = "black")#create the third bar plus 1 width
rects2 = ax.bar(x +0.5*width,
               df_Reg["2006"],
               width = width,
               label = 2006,
               edgecolor = "black")#create the fourth bar
rects3 = ax.bar(x + 1.5*width,
               df_Reg["2011"],
               width = width,
               label = 2011,
               edgecolor = "black")#create the fifth bar
rects4 = ax.bar(x +2.2*width,
               df_Reg["2016"],
              width = width,
               label = 2016,
               edgecolor = "black")#add the labels to the axis
ax.set_ylabel("Unemployment rate",
             fontsize = 25,
             labelpad = 20)
ax.set_xlabel("SGC",
             fontsize = 25,
             labelpad =20)
ax.set_title("Unemployment Rate in North Coast and Nechako Economic Region",
            fontsize = 30,
            pad = 20)#set the ticks
#using the labels
ax.set_xticks(x)
ax.set_xticklabels(label)#add the legend
ax.legend(title = "Year of census",
         fontsize = 16,
         title_fontsize = 20,
         bbox_to_anchor = (1.02, 0.7))#adjust the tick paramaters
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 300,
              labelsize = 20)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 20)

# %%
df_R1 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/Region_1.csv')
df_R1
# Out:
#    Year  SGC Code        Geography  Unemployment rate     Rt
# 0  1996      5949  Kitimat-Stikine               13.7  13.86
# 1  2001      5949  Kitimat-Stikine               17.1  15.25
# 2  2006      5949  Kitimat-Stikine               14.2  12.71
# 3  2011      5949  Kitimat-Stikine               12.9  12.19
# 4  2016      5949  Kitimat-Stikine               13.8  12.98

# %%
df_1=df_R1[["Unemployment rate", "Rt"]]
df_1
# Out:
#    Unemployment rate     Rt
# 0               13.7  13.86
# 1               17.1  15.25
# 2               14.2  12.71
# 3               12.9  12.19
# 4               13.8  12.98

# %%
df_1.shape
# Out:
# (5, 2)

# %%
plt.figure(figsize=(16, 8))
df_1.plot.scatter(x="Rt", y="Unemployment rate", title='Scatterplot of Unemployed and Unemployment rate in Kitimat-Stikine ')
# Out:
# <AxesSubplot:title={'center':'Scatterplot of Unemployed and Unemployment rate in Kitimat-Stikine '}, xlabel='Rt', ylabel='Unemployment rate'>

# %%
print(df_1.corr())
# Out:
#                    Unemployment rate        Rt
# Unemployment rate           1.000000  0.888787
# Rt                          0.888787  1.000000

# %%
print(df_1.describe().round(2).T)
# Out:
#                    count   mean   std    min    25%    50%    75%    max
# Unemployment rate    5.0  14.34  1.61  12.90  13.70  13.80  14.20  17.10
# Rt                   5.0  13.40  1.20  12.19  12.71  12.98  13.86  15.25

# %%
df_R2 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/Region_2.csv')
df_R2
# Out:
#    Year  SGC Code               Geography  Unemployment rate     Rt
# 0  1996      5947  Skeena-Queen Charlotte               16.5  13.86
# 1  2001      5947  Skeena-Queen Charlotte               16.5  15.25
# 2  2006      5947  Skeena-Queen Charlotte               15.0  12.71
# 3  2011      5947  Skeena-Queen Charlotte               14.2  12.19
# 4  2016      5947  Skeena-Queen Charlotte               12.3  12.98

# %%
df_2=df_R2[["Unemployment rate", "Rt"]]
df_2
# Out:
#    Unemployment rate     Rt
# 0               16.5  13.86
# 1               16.5  15.25
# 2               15.0  12.71
# 3               14.2  12.19
# 4               12.3  12.98

# %%
df_2.plot.scatter(x="Rt", y="Unemployment rate", title='Scatterplot of Unemployed and Unemployment rate in Skeena-Queen Charlotte')
# Out:
# <AxesSubplot:title={'center':'Scatterplot of Unemployed and Unemployment rate in Skeena-Queen Charlotte'}, xlabel='Rt', ylabel='Unemployment rate'>

# %%
print(df_2.corr())
# Out:
#                    Unemployment rate        Rt
# Unemployment rate           1.000000  0.659665
# Rt                          0.659665  1.000000

# %%
print(df_2.describe().round(2).T)
# Out:
#                    count  mean   std    min    25%    50%    75%    max
# Unemployment rate    5.0  14.9  1.76  12.30  14.20  15.00  16.50  16.50
# Rt                   5.0  13.4  1.20  12.19  12.71  12.98  13.86  15.25

# %%
df_R3 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/Region_3.csv')
df_R3
# Out:
#    Year  SGC Code         Geography  Unemployment rate     Rt
# 0  1996      5951  Bulkley-Nechako                12.5  13.86
# 1  2001      5951  Bulkley-Nechako                12.6  15.25
# 2  2006      5951  Bulkley-Nechako                10.3  12.71
# 3  2011      5951  Bulkley-Nechako                10.5  12.19
# 4  2016      5951  Bulkley-Nechako                12.3  12.98

# %%
df_3=df_R3[["Unemployment rate", "Rt"]]
df_3
# Out:
#    Unemployment rate     Rt
# 0               12.5  13.86
# 1               12.6  15.25
# 2               10.3  12.71
# 3               10.5  12.19
# 4               12.3  12.98

# %%
df_3.plot.scatter(x="Rt", y="Unemployment rate", title='Scatterplot of Unemployed and Unemployment rate in Bulkley-Nechako')
# Out:
# <AxesSubplot:title={'center':'Scatterplot of Unemployed and Unemployment rate in Bulkley-Nechako'}, xlabel='Rt', ylabel='Unemployment rate'>

# %%
print(df_3.corr())
# Out:
#                    Unemployment rate        Rt
# Unemployment rate           1.000000  0.768346
# Rt                          0.768346  1.000000

# %%
print(df_3.describe().round(2).T)
# Out:
#                    count   mean   std    min    25%    50%    75%    max
# Unemployment rate    5.0  11.64  1.14  10.30  10.50  12.30  12.50  12.60
# Rt                   5.0  13.40  1.20  12.19  12.71  12.98  13.86  15.25

# %%
df_R4 = pd.read_csv('C:/Users/hamme/Desktop/Folders__/M2PI/census_if/census_lf/Region_4.csv')
df_R4
# Out:
#    Year  SGC Code Geography  Unemployment rate     Rt
# 0  1996      5957   Stikine                9.7  13.86
# 1  2001      5957   Stikine               18.1  15.25
# 2  2006      5957   Stikine               10.1  12.71
# 3  2011      5957   Stikine               19.4  12.19
# 4  2016      5957   Stikine               23.5  12.98

# %%
df_4=df_R4[["Unemployment rate", "Rt"]]
df_4
# Out:
#    Unemployment rate     Rt
# 0                9.7  13.86
# 1               18.1  15.25
# 2               10.1  12.71
# 3               19.4  12.19
# 4               23.5  12.98

# %%
df_4.plot.scatter(x="Rt", y="Unemployment rate", title='Scatterplot of Unemployed and Unemployment rate in Stikine')
# Out:
# <AxesSubplot:title={'center':'Scatterplot of Unemployed and Unemployment rate in Stikine'}, xlabel='Rt', ylabel='Unemployment rate'>

# %%
print(df_4.corr())
# Out:
#                    Unemployment rate        Rt
# Unemployment rate           1.000000 -0.075923
# Rt                         -0.075923  1.000000

# %%
print(df_4.describe().round(2).T)
# Out:
#                    count   mean   std    min    25%    50%    75%    max
# Unemployment rate    5.0  16.16  6.05   9.70  10.10  18.10  19.40  23.50
# Rt                   5.0  13.40  1.20  12.19  12.71  12.98  13.86  15.25

# %%
y=df_1["Unemployment rate"].values.reshape(-1,1)
X=df_1["Rt"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
SEED = 42

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = SEED)
#print(X_train) 
#print(y_train)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [9.33627076]

# %%
print(regressor.coef_)
# Out:
# [[0.33349279]]

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[14.42203581]])

# %%
y_error = y_test - y_pred
y_error
# Out:
# array([[2.67796419]])

# %%
r_sq = regressor.score(X, y)
r_sq
# Out:
# 0.24138035688622805

# %%
import statsmodels.formula.api as sm

# %%
lm2 = sm.OLS(y_train,X_train).fit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-174-841081eccd0c> in <module>
# ----> 1 lm2 = sm.OLS(y_train,X_train).fit()
#
# AttributeError: module 'statsmodels.formula.api' has no attribute 'OLS'
